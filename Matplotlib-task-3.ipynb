# %%
#task 3 
#matplotlib
# !pip install matplotlib
import matplotlib.pyplot as plt

# %%
#Basic plotting
x=[2,4,6,8,0]
y=[1,3,5,7,9]
plt.plot(y,x)
plt.show()

# %%
#2
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x,y,marker='d',linestyle='--')
plt.show()
"""Marker	Symbol	Meaning
'o'	●	Circle
's'	■	Square
'^'	▲	Triangle up
'v'	▼	Triangle down
'D'	◆	Diamond
'+'	+	Plus
'x'	×	Cross
'*'	★	Star
'.'	•	Point"""
# Out:
# "Marker\tSymbol\tMeaning\n'o'\t●\tCircle\n's'\t■\tSquare\n'^'\t▲\tTriangle up\n'v'\t▼\tTriangle down\n'D'\t◆\tDiamond\n'+'\t+\tPlus\n'x'\t×\tCross\n'*'\t★\tStar\n'.'\t•\tPoint"

# %%
#3
plt.plot(x,y)
plt.title("x-y graph")
plt.xlabel("x values")
plt.ylabel("y values")
# Out:
# Text(0, 0.5, 'y values')

# %%
#4
y2=[5,7,3,2,0]
plt.plot(x,y,label="line 1")
plt.plot(x,y2,label="line 2")
plt.legend()
plt.show()

# %%
#5
plt.plot(x)
plt.plot(y)
plt.xlim(0,5)
plt.ylim(0,12)
plt.show()

# %%
#6
plt.plot(x,y)
plt.grid(True)
plt.show()

# %%
#7
plt.plot(y2,y)
plt.savefig("line_plot.png")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(y,y2)
plt.show()
plt.clf()

# %% [markdown]
# Part B: Scatter & Bar Plots

# %%
#Create a scatter plot
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y,color='pink',s=100,marker='s')
plt.show()

# %%
plt.bar(x,y,color='pink')
plt.show()

# %%
plt.barh(x,y2,color='pink')
plt.show()

# %%
plt.bar(x,y)
for i in range(len(x)):
    plt.text(x[i],y[i],y[i])
plt.show()

# %%
import numpy as np
x=np.arange(3)
a=[3,5,7]
b=[4,6,8]
plt.bar(x-0.2,a,width=0.4,label="Group A")
plt.bar(x+0.2,b,width=0.4,label="Group B")
plt.legend()
plt.show()

# %%
plt.bar(x, a, label="A")
plt.bar(x, b, bottom=a, label="B")
plt.legend()
plt.show()

# %%
plt.bar(x, a)
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(x, a, width=0.3)
plt.show()

# %%
plt.bar(x, a, color='green')
plt.show()

# %% [markdown]
# PART C: HISTOGRAM & BOX PLOT

# %%
data=np.random.randn(100)
plt.hist(data)
plt.show()

# %%
plt.hist(data, bins=20)
plt.show()

# %%
plt.hist(data, density=True)
plt.show()

# %%
plt.hist(data)
plt.hist(data + 1)
plt.show()

# %%
plt.boxplot(data)
plt.show()

# %%
plt.boxplot(data, patch_artist=True)
plt.show()

# %%
plt.boxplot([data, data + 2])
plt.show()

# %%
import numpy as np
import scipy.stats
from scipy import stats
a=np.array([30,36,47,50,52,52,56,60,63,70,70,110])
print(np.mean(a))
print(np.median(a))
print(stats.mode(a))
print(np.var(a))
print(np.std(a))
#b=min(a)
#c=max(a)
#print((a+b)/2)
b=((np.min(a)+np.max(a))/2)
print(b)
q1=np.percentile(a,25)
q3=np.percentile(a,75)
print(q3-q1)
# Out:
# 58.0
# 54.0
# ModeResult(mode=np.int64(52), count=np.int64(2))
# 379.1666666666667
# 19.47220240924654
# 70.0
# 15.5

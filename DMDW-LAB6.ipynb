# %%
import pandas as pd

df = pd.read_csv("weather_missing.csv")

print(df)
print(df.isnull())
print(df.isnull().sum())
# Out:
#    Day  Temperature  Humidity  Windy
# 0  Mon         72.0      80.0   True
# 1  Tue          NaN      85.0  False
# 2  Wed         75.0       NaN   True
# 3  Thu         80.0      90.0    NaN
# 4  Fri          NaN      88.0  False
# 5  Sat         77.0       NaN   True
# 6  Sun         78.0      82.0    NaN
#      Day  Temperature  Humidity  Windy
# 0  False        False     False  False
# 1  False         True     False  False
# 2  False        False      True  False
# 3  False        False     False   True
# 4  False         True     False  False
# 5  False        False      True  False
# 6  False        False     False   True
# Day            0
# Temperature    2
# Humidity       2
# Windy          2
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv("weather_missing.csv")

df["Temperature"].fillna(80, inplace=True)

print(df)
# Out:
#    Day  Temperature  Humidity  Windy
# 0  Mon         72.0      80.0   True
# 1  Tue          NaN      85.0  False
# 2  Wed         75.0       NaN   True
# 3  Thu         80.0      90.0    NaN
# 4  Fri          NaN      88.0  False
# 5  Sat         77.0       NaN   True
# 6  Sun         78.0      82.0    NaN
# /tmp/ipykernel_30015/1947300565.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("weather_missing.csv")

df["Humidity"].fillna(90, inplace=True)

print(df)
# Out:
#    Day  Temperature  Humidity  Windy
# 0  Mon         72.0      80.0   True
# 1  Tue          NaN      85.0  False
# 2  Wed         75.0       NaN   True
# 3  Thu         80.0      90.0    NaN
# 4  Fri          NaN      88.0  False
# 5  Sat         77.0       NaN   True
# 6  Sun         78.0      82.0    NaN
# /tmp/ipykernel_30015/2699187277.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("weather_missing.csv")

df = df.dropna(subset=["Windy"])

print(df)
# Out:
#    Day  Temperature  Humidity  Windy
# 0  Mon         72.0      80.0   True
# 1  Tue          NaN      85.0  False
# 2  Wed         75.0       NaN   True
# 4  Fri          NaN      88.0  False
# 5  Sat         77.0       NaN   True

# %%
pip install scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 21.9 MB/s  0:00:00m0:00:010:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn] [scikit-learn]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv("person.csv")

cols = ["Salary","Year_of_experience","Expected_Position_Level"]

scaler = MinMaxScaler()

df[cols] = scaler.fit_transform(df[cols])

print(df)
# Out:
#   person_name    Salary  Year_of_experience  Expected_Position_Level
# 0        Aman  0.772727                 0.5                 0.142857
# 1     Abhinav  0.522727                 0.2                 0.428571
# 2    Ashutosh  0.000000                 0.0                 1.000000
# 3       Dishi  0.261364                 0.1                 0.857143
# 4    Abhishek  0.681818                 0.3                 0.285714
# 5    Avantika  1.000000                 1.0                 0.000000
# 6      Ayushi  0.383523                 0.2                 0.571429

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

df = pd.read_csv("person.csv")

cols = ["Salary","Year_of_experience","Expected_Position_Level"]

scaler = StandardScaler()

df[cols] = scaler.fit_transform(df[cols])

print(df)
# Out:
#   person_name    Salary  Year_of_experience  Expected_Position_Level
# 0        Aman  0.821254            0.552345                -0.963087
# 1     Abhinav  0.016973           -0.414259                -0.120386
# 2    Ashutosh -1.664704           -1.058661                 1.565016
# 3       Dishi -0.823865           -0.736460                 1.143666
# 4    Abhishek  0.528788           -0.092057                -0.541736
# 5    Avantika  1.552418            2.163350                -1.384437
# 6      Ayushi -0.430864           -0.414259                 0.300965

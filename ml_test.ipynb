# %% [markdown]
# Generate a dataset via scikit learn and perform linear regression on it by ensuring assumptions of linear regression
# DATASET SIZE: FEATURE: 4
#               RESPONSES : 1
#               EXAMPLES : 1000
